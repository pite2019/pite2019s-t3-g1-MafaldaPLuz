# %%
import sklearn
import sklearn.datasets
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# **Read boston dataset and printed head of the dataset**

# %%
boston = sklearn.datasets.load_boston()
dataset_boston = boston.data

df = pd.DataFrame(data = dataset_boston, columns = boston.feature_names)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# **Histograms with the columns INDUS and NOX**

# %%
df.hist(column=[ 'AGE','NOX'],bins=13)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D26A409D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D26A444FD0>]],
#       dtype=object)

# %% [markdown]
# **LinearRegression**

# %%
from sklearn.linear_model import LinearRegression

boston_target = boston.target
X = df['AGE']
Z = df['NOX']
Y = pd.DataFrame(data = boston_target)

regression = LinearRegression().fit(df,Y)
predicted = regression.predict(df)

plt.scatter(Y, predicted)
plt.xlabel('Price')
plt.ylabel('Predicted')
plt.show()

print("The score is:"+str(regression.score(df,Y)))
# Out:
# The score is:0.7406077428649428

# %% [markdown]
# **Two plots of each of the picked columns**

# %%
plt.scatter(X,Y)
plt.xlabel('AGE')
plt.ylabel('Price')
# Out:
# Text(0,0.5,'Price')

# %%
plt.plot(X,predicted)

# %% [markdown]
# The target here is strongly positive.

# %%
plt.scatter(Z,Y)
plt.xlabel('NOX')
plt.ylabel('Price')
# Out:
# Text(0,0.5,'Price')

# %%
plt.plot(Z,predicted)

# %% [markdown]
# The target here is weakly positive.
